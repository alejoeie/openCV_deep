# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open("1.jpeg")

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1280 at 0x25E6C315470>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1280, 960, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1280, 960, 3)

# %%
# R G B

#Valores de color rojo
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1])

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
#Canal Verde
pic_red[:,:,1] = 0

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1280, 960, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-8d174c9c87a6> in <module>
# ----> 1 pic_red[:,:,3] = 0
#
# IndexError: index 3 is out of bounds for axis 2 with size 3
